# %%
import typing as tp
from dataclasses import dataclass

import networkx as nx
import osmnx as ox
from shapely.geometry import LineString, Point
from tqdm import tqdm
import copy
import folium


class PathFinder:

    def __init__(
            self,
            start_point: tp.Tuple[float, float],
            end_point: tp.Tuple[float, float],
        ):
        self.graph: tp.Union[nx.Graph, nx.MultiDiGraph, None] = None
        self.start_point = start_point
        self.end_point = end_point

    def load_graph(self, radius_from_path: int = 50_000):
        """
        `radius_from_path` is given in meters.
        """
        line = LineString([self.start_point, self.end_point])
        buffered_polygon = line.buffer(radius_from_path)
        self.graph = ox.graph_from_polygon(buffered_polygon, network_type="all")
    

    def load_graph_from_region(self):
        region = 'Małopolskie Voivodeship, Poland'  # Adjust the region as needed
    
        # Download the street network for the region
        self.graph = ox.graph_from_place(region, network_type='all')

    def load_graph_from_radius(self, radius: int):
        self.graph = ox.graph_from_point(self.start_point, dist=radius, network_type='all')

    def save_graph(self):
        ox.save_graphml(self.graph, filepath="graph.graphml")

    def load_from_file(self, filepath: str = "graph.graphml"):
        self.graph = ox.load_graphml(filepath)

    def load_criteria(self):
        ATTRACTIVENESS = "attractiveness"
        for u, v, key, data in tqdm(self.graph.edges(keys=True, data=True)):
            
            # Adding attractiveness
            data[ATTRACTIVENESS] = data['length']

            # Weighting/excluding by speed
            if 'maxspeed' in data:
                for speed in list(data['maxspeed']):
                    try:
                        speed_value = int(speed)
                    except:
                        continue
                    if speed_value in range(0, 30):
                        penalty = 1
                    elif speed_value in range(30, 50):
                        penalty = 2
                    elif speed_value in range(50, 90):
                        penalty = 3
                    elif speed_value > 90:
                        penalty = 4
                    data[ATTRACTIVENESS] *= penalty

            # Weighting/excluding by type
            if 'highway' in data and data['highway'] == 'cycleway': # 'tertiary']:
                data[ATTRACTIVENESS] *= 2
            if 'highway' in data and data['highway'] == 'tertiary':
                data[ATTRACTIVENESS] *= 2

    def find_path(self):
        # Get nearest nodes to points A and B
        a_node = ox.distance.nearest_nodes(self.graph, self.start_point[1], self.start_point[0])
        b_node = ox.distance.nearest_nodes(self.graph, self.end_point[1], self.end_point[0])

        print("Finding shortest...")
        # Find the shortest path using custom weights
        shortest_path = nx.shortest_path(self.graph, a_node, b_node, weight='length')
        print("Found!")

        # Plot the graph and the shortest path
        # ox.plot_graph_route(self.graph, shortest_path)

        # Output path distance in meters
        distance = nx.shortest_path_length(self.graph, a_node, b_node, weight='length')
        print(f"Shortest path distance: {distance} meters")

        self.path = shortest_path

    def show_path(self):
        # Create a map centered on point A
        m = folium.Map(location=self.start_point, zoom_start=12)

        # Plot the shortest path based on edge geometries
        for u, v, key in zip(self.path[:-1], self.path[1:], range(len(self.path)-1)):
            # Retrieve edge data and check if it has a geometry (for curved roads)
            edge_data = self.graph.get_edge_data(u, v)
            print(edge_data)
            
            if 'geometry' in edge_data:
                # If edge has geometry (linestring), extract and plot the full geometry
                coords = list(edge_data['geometry'].coords)
            else:
                # If no geometry, plot a straight line between nodes
                coords = [(self.graph.nodes[u]['y'], self.graph.nodes[u]['x']),
                        (self.graph.nodes[v]['y'], self.graph.nodes[v]['x'])]
            
            # Add the segment to the map
            folium.PolyLine(coords, color="blue", weight=5, opacity=0.7).add_to(m)

        # Add markers for start (point A) and end (point B)
        folium.Marker(location=self.start_point, popup="Start: Point A", icon=folium.Icon(color="green")).add_to(m)
        folium.Marker(location=self.end_point, popup="End: Point B", icon=folium.Icon(color="red")).add_to(m)

        # Display the map
        return m

# %%
nowy_sacz = (49.639989612887234, 20.69236640147815)
nowy_targ: tuple[float, float] = (49.48271570006089, 20.0370067919616)

# %%
# pf = PathFinder(
#     nowy_sacz,
#     nowy_targ,
# )

# %%
pf2 = PathFinder(
    nowy_sacz,
    nowy_targ,
)
pf2.graph = pf.graph
pf = pf2

# %%
# pf.load_graph_from_region()

# %%
# pf.save_graph()

# %%
# pf.load_from_file()

# %%
pf.load_criteria()
# Out:
#  19%|█▉        | 340162/1757555 [00:00<00:02, 544243.03it/s]
# P
# L
# :
# r
# u
# r
# a
# l
# P
# L
# :
# u
# r
# b
# a
# n
# P
# L
# :
# u
# r
# b
# a
# n
# P
# L
# :
# u
# r
# b
# a
# n
#  35%|███▍      | 613160/1757555 [00:01<00:02, 485589.78it/s]
# P
# L
# :
# r
# u
# r
# a
# l
# PL:urban
# PL:rural
# P
# L
# :
# u
# r
# b
# a
# n
# PL:urban
# PL:rural
#  59%|█████▉    | 1042410/1757555 [00:02<00:01, 504219.68it/s]
# P
# L
# :
# u
# r
# b
# a
# n
# PL:urban
# P
# L
# :
# u
# r
# b
# a
# n
# P
# L
# :
# u
# r
# b
# a
# n
# P
# L
# :
# u
# r
# b
# a
# n
# PL:urban
#  82%|████████▏ | 1445549/1757555 [00:02<00:00, 472602.70it/s]
# PL:rural
# PL:rural
# 100%|██████████| 1757555/1757555 [00:03<00:00, 497009.10it/s]

# %%
pf.find_path()
# Out:
# Finding shortest...
# Found!
# Shortest path distance: 41521.73200000002 meters

# %%
pf.show_path()
# Out:
# {0: {'osmid': 75084154, 'name': 'Powstańców Śląskich', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 123.047, 'attractiveness': 123.047}}
# {0: {'osmid': 75084183, 'name': 'Powstańców Wielkopolskich', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 47.278, 'geometry': <LINESTRING (20.692 49.639, 20.692 49.639, 20.692 49.639)>, 'attractiveness': 47.278}}
# {0: {'osmid': 75084183, 'name': 'Powstańców Wielkopolskich', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 77.222, 'geometry': <LINESTRING (20.692 49.639, 20.691 49.639, 20.69 49.639)>, 'attractiveness': 77.222}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 11.264, 'attractiveness': 11.264}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 36.439, 'attractiveness': 36.439}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 95.34700000000001, 'geometry': <LINESTRING (20.69 49.639, 20.689 49.639, 20.689 49.639, 20.689 49.639)>, 'attractiveness': 95.34700000000001}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 41.065999999999995, 'geometry': <LINESTRING (20.689 49.639, 20.688 49.639, 20.688 49.639, 20.688 49.639)>, 'attractiveness': 41.065999999999995}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 40.101, 'geometry': <LINESTRING (20.688 49.639, 20.687 49.639, 20.687 49.639)>, 'attractiveness': 40.101}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 45.824, 'geometry': <LINESTRING (20.687 49.639, 20.687 49.639, 20.687 49.639, 20.687 49.639)>, 'attractiveness': 45.824}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 51.159, 'geometry': <LINESTRING (20.687 49.639, 20.687 49.639, 20.686 49.639, 20.686 49.639)>, 'attractiveness': 51.159}}
# {0: {'osmid': 353598389, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 22.547, 'attractiveness': 22.547}}
# {0: {'osmid': 1091628318, 'oneway': False, 'name': 'Warzywna', 'highway': 'residential', 'reversed': False, 'length': 17.027, 'geometry': <LINESTRING (20.686 49.639, 20.686 49.639, 20.686 49.639)>, 'attractiveness': 17.027}}
# {0: {'osmid': 335068574, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 267.514, 'geometry': <LINESTRING (20.686 49.639, 20.686 49.639, 20.686 49.639, 20.686 49.639, 20....>, 'attractiveness': 535.028}}
# {0: {'osmid': 689547995, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 99.525, 'geometry': <LINESTRING (20.688 49.635, 20.688 49.634, 20.688 49.634, 20.688 49.634, 20....>, 'attractiveness': 199.05}}
# {0: {'osmid': 688577696, 'oneway': False, 'name': 'Rybacka', 'highway': 'unclassified', 'reversed': True, 'length': 123.964, 'geometry': <LINESTRING (20.688 49.633, 20.688 49.633, 20.688 49.633, 20.689 49.633, 20....>, 'attractiveness': 123.964}}
# {0: {'osmid': [211055488, 643968485, 688577071, 75084180, 971099837, 688577695], 'highway': 'cycleway', 'oneway': False, 'reversed': [False, True], 'length': 199.40300000000002, 'bridge': 'yes', 'name': 'Kładka nad Kamienicą', 'width': '2.5', 'geometry': <LINESTRING (20.689 49.632, 20.689 49.632, 20.689 49.632, 20.689 49.631, 20....>, 'attractiveness': 398.80600000000004}}
# {0: {'osmid': 971099846, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 158.66, 'geometry': <LINESTRING (20.688 49.629, 20.688 49.629, 20.688 49.628, 20.688 49.628, 20....>, 'attractiveness': 317.32}}
# {0: {'osmid': 740016131, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 268.6965, 'geometry': <LINESTRING (20.687 49.626, 20.687 49.626, 20.687 49.626, 20.687 49.626, 20....>, 'attractiveness': 537.393}}
# {0: {'osmid': 740016131, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 44.94650000000001, 'geometry': <LINESTRING (20.685 49.622, 20.685 49.621, 20.685 49.622, 20.685 49.622, 20....>, 'attractiveness': 89.89300000000001}}
# {0: {'osmid': 740016131, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 1.854, 'attractiveness': 3.708}}
# {0: {'osmid': 544415410, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 79.72, 'geometry': <LINESTRING (20.686 49.622, 20.686 49.621, 20.685 49.621, 20.685 49.621)>, 'attractiveness': 159.44}}
# {0: {'osmid': 544415410, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 99.488, 'geometry': <LINESTRING (20.685 49.621, 20.685 49.619, 20.685 49.619)>, 'attractiveness': 198.976}}
# {0: {'osmid': 544415410, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 55.4085, 'attractiveness': 110.817}}
# {0: {'osmid': 544415410, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 92.5735, 'attractiveness': 185.147}}
# {0: {'osmid': 544415410, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 310.6965, 'geometry': <LINESTRING (20.684 49.616, 20.683 49.616, 20.683 49.615, 20.683 49.615, 20....>, 'attractiveness': 621.393}}
# {0: {'osmid': 544415411, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 33.038, 'geometry': <LINESTRING (20.68 49.611, 20.68 49.612, 20.68 49.612)>, 'attractiveness': 33.038}}
# {0: {'osmid': 973064484, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 16.533, 'attractiveness': 16.533}}
# {0: {'osmid': 973064484, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 197.52300000000002, 'geometry': <LINESTRING (20.679 49.612, 20.679 49.612, 20.679 49.611, 20.679 49.611, 20....>, 'attractiveness': 197.52300000000002}, 1: {'osmid': 973064485, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 173.39000000000001, 'geometry': <LINESTRING (20.679 49.612, 20.679 49.612, 20.679 49.611, 20.679 49.611, 20....>, 'attractiveness': 173.39000000000001}}
# {0: {'osmid': [1165124116, 1165124102, 1165124103], 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 23.591, 'geometry': <LINESTRING (20.677 49.611, 20.677 49.611, 20.677 49.611, 20.677 49.611, 20....>, 'attractiveness': 23.591}}
# {0: {'osmid': 1165124118, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 4.591, 'attractiveness': 4.591}}
# {0: {'osmid': 1165124113, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 474.76500000000004, 'geometry': <LINESTRING (20.677 49.611, 20.677 49.611, 20.677 49.611, 20.677 49.61, 20.6...>, 'attractiveness': 474.76500000000004}}
# {0: {'osmid': [1290670722, 1165124100, 1165124101], 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 33.754, 'width': '2', 'geometry': <LINESTRING (20.673 49.607, 20.673 49.607, 20.673 49.607, 20.673 49.607, 20....>, 'attractiveness': 33.754}}
# {0: {'osmid': 1290670722, 'highway': 'track', 'width': '2', 'oneway': False, 'reversed': False, 'length': 2.401, 'attractiveness': 2.401}}
# {0: {'osmid': 544415414, 'highway': 'cycleway', 'width': '2', 'oneway': False, 'reversed': False, 'length': 197.091, 'geometry': <LINESTRING (20.673 49.607, 20.673 49.607, 20.673 49.607, 20.673 49.607, 20....>, 'attractiveness': 394.182}}
# {0: {'osmid': 544415414, 'highway': 'cycleway', 'width': '2', 'oneway': False, 'reversed': False, 'length': 203.27949999999996, 'geometry': <LINESTRING (20.671 49.604, 20.671 49.604, 20.671 49.604, 20.671 49.603, 20....>, 'attractiveness': 406.5589999999999}}
# {0: {'osmid': [359859354, 359859355, 544415414], 'highway': 'cycleway', 'width': '2', 'oneway': False, 'reversed': False, 'length': 363.994, 'geometry': <LINESTRING (20.669 49.6, 20.669 49.6, 20.669 49.6, 20.668 49.6, 20.668 49.6...>, 'attractiveness': 727.988}}
# {0: {'osmid': 359859355, 'highway': 'cycleway', 'width': '2', 'oneway': False, 'reversed': False, 'length': 332.0135, 'geometry': <LINESTRING (20.661 49.597, 20.66 49.597, 20.659 49.596, 20.659 49.596, 20.6...>, 'attractiveness': 664.027}}
# {0: {'osmid': [359859355, 359861364], 'highway': 'cycleway', 'width': ['2.5', '2'], 'oneway': False, 'reversed': False, 'length': 258.583, 'geometry': <LINESTRING (20.655 49.593, 20.655 49.592, 20.655 49.592, 20.654 49.591, 20....>, 'attractiveness': 517.166}}
# {0: {'osmid': [359861368, 359861364, 359861367], 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 362.7485, 'geometry': <LINESTRING (20.654 49.588, 20.654 49.588, 20.654 49.587, 20.654 49.586, 20....>, 'attractiveness': 725.497}}
# {0: {'osmid': 359861368, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 8.4725, 'attractiveness': 16.945}}
# {0: {'osmid': 359861368, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': False, 'length': 43.42400000000001, 'geometry': <LINESTRING (20.654 49.581, 20.654 49.581, 20.654 49.581)>, 'attractiveness': 86.84800000000001}}
# {0: {'osmid': 360479734, 'highway': 'cycleway', 'width': '2.5', 'oneway': False, 'reversed': True, 'length': 22.596000000000004, 'geometry': <LINESTRING (20.654 49.581, 20.654 49.58, 20.654 49.58, 20.654 49.58)>, 'attractiveness': 45.19200000000001}}
# {0: {'osmid': 205097278, 'highway': 'service', 'oneway': False, 'reversed': False, 'length': 85.05199999999999, 'geometry': <LINESTRING (20.654 49.58, 20.654 49.58, 20.654 49.58, 20.653 49.58, 20.653 ...>, 'attractiveness': 85.05199999999999}}
# {0: {'osmid': 205097278, 'highway': 'service', 'oneway': False, 'reversed': False, 'length': 17.548000000000002, 'geometry': <LINESTRING (20.653 49.58, 20.653 49.58, 20.653 49.58)>, 'attractiveness': 17.548000000000002}}
# {0: {'osmid': 205097278, 'highway': 'service', 'oneway': False, 'reversed': False, 'length': 27.734, 'geometry': <LINESTRING (20.653 49.58, 20.653 49.58, 20.652 49.58)>, 'attractiveness': 27.734}}
# {0: {'osmid': [632614243, 1292627979, 1292627980, 644940178, 657440532, 644940181, 620985046], 'highway': 'cycleway', 'oneway': False, 'reversed': [False, True], 'length': 131.38999999999996, 'bridge': 'yes', 'geometry': <LINESTRING (20.652 49.58, 20.652 49.58, 20.652 49.58, 20.652 49.579, 20.652...>, 'attractiveness': 262.7799999999999}}
# {0: {'osmid': 620985050, 'highway': 'cycleway', 'oneway': False, 'reversed': True, 'length': 65.607, 'geometry': <LINESTRING (20.652 49.578, 20.651 49.577, 20.651 49.577, 20.651 49.577, 20....>, 'attractiveness': 131.214}}
# {0: {'osmid': 1091647779, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 43.516, 'geometry': <LINESTRING (20.65 49.577, 20.65 49.577, 20.65 49.577)>, 'attractiveness': 43.516}}
# {0: {'osmid': 359383684, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 223.458, 'geometry': <LINESTRING (20.65 49.577, 20.65 49.576, 20.65 49.576, 20.65 49.576, 20.649 ...>, 'attractiveness': 223.458}}
# {0: {'osmid': 359383684, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 39.518, 'geometry': <LINESTRING (20.648 49.575, 20.648 49.575, 20.648 49.575)>, 'attractiveness': 39.518}}
# {0: {'osmid': 972040465, 'highway': 'service', 'oneway': False, 'reversed': True, 'length': 133.34300000000002, 'geometry': <LINESTRING (20.648 49.575, 20.648 49.575, 20.648 49.574, 20.647 49.574, 20....>, 'attractiveness': 133.34300000000002}}
# {0: {'osmid': [972040465, 959571727], 'highway': 'service', 'oneway': False, 'reversed': True, 'length': 293.25, 'geometry': <LINESTRING (20.647 49.574, 20.647 49.573, 20.646 49.574, 20.646 49.574, 20....>, 'attractiveness': 293.25}}
# {0: {'osmid': 186461084, 'highway': 'service', 'service': 'driveway', 'oneway': False, 'reversed': True, 'length': 68.719, 'geometry': <LINESTRING (20.644 49.575, 20.644 49.575, 20.644 49.575, 20.643 49.575, 20....>, 'attractiveness': 68.719}}
# {0: {'osmid': 186461084, 'highway': 'service', 'service': 'driveway', 'oneway': False, 'reversed': True, 'length': 7.953, 'attractiveness': 7.953}}
# {0: {'osmid': 972353492, 'name': 'Prymasa Stefana Wyszyńskiego', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 206.3375, 'geometry': <LINESTRING (20.643 49.575, 20.642 49.574, 20.642 49.574, 20.642 49.574, 20....>, 'attractiveness': 412.675}}
# {0: {'osmid': 972353492, 'name': 'Prymasa Stefana Wyszyńskiego', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 12.439, 'attractiveness': 24.878}}
# {0: {'osmid': 972353492, 'name': 'Prymasa Stefana Wyszyńskiego', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 7.9045, 'attractiveness': 15.809}}
# {0: {'osmid': 972353492, 'name': 'Prymasa Stefana Wyszyńskiego', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 42.571, 'geometry': <LINESTRING (20.637 49.574, 20.637 49.574, 20.636 49.574, 20.636 49.574)>, 'attractiveness': 85.142}}
# {0: {'osmid': 972353492, 'name': 'Prymasa Stefana Wyszyńskiego', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 2.5205, 'attractiveness': 5.041}}
# {0: {'osmid': 608131013, 'oneway': False, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'reversed': False, 'length': 8.919, 'attractiveness': 17.838}}
# {0: {'osmid': 608131013, 'oneway': False, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'reversed': False, 'length': 94.4615, 'geometry': <LINESTRING (20.636 49.574, 20.636 49.573, 20.636 49.572, 20.636 49.572)>, 'attractiveness': 188.923}}
# {0: {'osmid': 608131013, 'oneway': False, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'reversed': False, 'length': 15.0665, 'attractiveness': 30.133}}
# {0: {'osmid': 608131013, 'oneway': False, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'reversed': False, 'length': 20.0375, 'attractiveness': 40.075}}
# {0: {'osmid': 608131013, 'oneway': False, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'reversed': False, 'length': 48.6895, 'attractiveness': 97.379}}
# {0: {'osmid': 608131003, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'oneway': False, 'reversed': False, 'length': 17.6, 'geometry': <LINESTRING (20.636 49.57, 20.636 49.57, 20.636 49.57)>, 'attractiveness': 35.2}}
# {0: {'osmid': 608131003, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'oneway': False, 'reversed': False, 'length': 42.834, 'geometry': <LINESTRING (20.636 49.57, 20.636 49.57, 20.636 49.569, 20.636 49.569)>, 'attractiveness': 85.668}}
# {0: {'osmid': 608131003, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'oneway': False, 'reversed': False, 'length': 15.694500000000001, 'geometry': <LINESTRING (20.636 49.569, 20.636 49.569, 20.636 49.569)>, 'attractiveness': 31.389000000000003}}
# {0: {'osmid': 608131003, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'oneway': False, 'reversed': False, 'length': 15.082, 'attractiveness': 30.164}}
# {0: {'osmid': 608131003, 'lanes': '2', 'name': 'Wielki Wygon', 'highway': 'tertiary', 'maxspeed': '60', 'oneway': False, 'reversed': False, 'length': 6.533, 'geometry': <LINESTRING (20.636 49.569, 20.636 49.569, 20.636 49.569)>, 'attractiveness': 13.066}}
# {0: {'osmid': 283233558, 'name': 'Polna', 'highway': 'tertiary', 'maxspeed': '50', 'oneway': False, 'reversed': False, 'length': 16.6695, 'geometry': <LINESTRING (20.636 49.569, 20.636 49.569, 20.636 49.568)>, 'attractiveness': 33.339}}
# {0: {'osmid': 283233556, 'name': 'Braterstwa Ludów', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 5.8985, 'geometry': <LINESTRING (20.636 49.568, 20.636 49.568, 20.636 49.568)>, 'attractiveness': 11.797}}
# {0: {'osmid': 283233556, 'name': 'Braterstwa Ludów', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 116.4, 'geometry': <LINESTRING (20.636 49.568, 20.635 49.569, 20.635 49.569, 20.635 49.569, 20....>, 'attractiveness': 232.8}}
# {0: {'osmid': 283233556, 'name': 'Braterstwa Ludów', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 109.22099999999999, 'geometry': <LINESTRING (20.633 49.569, 20.631 49.569, 20.631 49.569, 20.63 49.569, 20.6...>, 'attractiveness': 218.44199999999998}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 1.8615, 'attractiveness': 3.723}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 28.616, 'attractiveness': 57.232}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 38.43, 'geometry': <LINESTRING (20.63 49.568, 20.63 49.568, 20.63 49.568)>, 'attractiveness': 76.86}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 44.8415, 'attractiveness': 89.683}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 5.9295, 'attractiveness': 11.859}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 31.135, 'geometry': <LINESTRING (20.63 49.567, 20.63 49.567, 20.63 49.567, 20.63 49.566, 20.63 4...>, 'attractiveness': 62.27}}
# {0: {'osmid': 101454145, 'name': 'Powstańców Chochołowskich', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 4.021, 'attractiveness': 8.042}}
# {0: {'osmid': 737863678, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 21.081500000000002, 'geometry': <LINESTRING (20.63 49.566, 20.63 49.566, 20.63 49.566, 20.63 49.566, 20.63 4...>, 'attractiveness': 42.163000000000004}}
# {0: {'osmid': 737863678, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 26.482999999999997, 'geometry': <LINESTRING (20.629 49.566, 20.629 49.566, 20.629 49.566, 20.629 49.566, 20....>, 'attractiveness': 52.965999999999994}}
# {0: {'osmid': 737863678, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 35.34, 'geometry': <LINESTRING (20.629 49.566, 20.628 49.566, 20.628 49.566, 20.628 49.566)>, 'attractiveness': 70.68}}
# {0: {'osmid': 750669048, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 20.4475, 'attractiveness': 40.895}}
# {0: {'osmid': 932140185, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 1.931, 'attractiveness': 3.862}}
# {0: {'osmid': 932140185, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 96.9585, 'geometry': <LINESTRING (20.627 49.566, 20.626 49.566, 20.626 49.566, 20.625 49.566, 20....>, 'attractiveness': 193.917}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 43.8965, 'geometry': <LINESTRING (20.624 49.565, 20.624 49.565, 20.624 49.565, 20.624 49.565, 20....>, 'attractiveness': 87.793}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 34.349000000000004, 'geometry': <LINESTRING (20.623 49.565, 20.623 49.565, 20.623 49.565, 20.622 49.565)>, 'attractiveness': 68.69800000000001}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 96.43199999999999, 'geometry': <LINESTRING (20.622 49.565, 20.622 49.565, 20.622 49.565, 20.622 49.565, 20....>, 'attractiveness': 192.86399999999998}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 26.4665, 'geometry': <LINESTRING (20.62 49.564, 20.62 49.564, 20.619 49.564)>, 'attractiveness': 52.933}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 14.838, 'attractiveness': 29.676}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 16.571, 'attractiveness': 33.142}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 12.3615, 'geometry': <LINESTRING (20.619 49.564, 20.619 49.564, 20.618 49.564)>, 'attractiveness': 24.723}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 13.716999999999999, 'geometry': <LINESTRING (20.618 49.564, 20.618 49.564, 20.618 49.564)>, 'attractiveness': 27.433999999999997}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 20.3705, 'attractiveness': 40.741}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 55.5895, 'attractiveness': 111.179}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 51.083, 'geometry': <LINESTRING (20.616 49.563, 20.616 49.563, 20.615 49.562)>, 'attractiveness': 102.166}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 13.766, 'attractiveness': 27.532}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 14.5885, 'attractiveness': 29.177}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 28.953000000000003, 'geometry': <LINESTRING (20.614 49.562, 20.614 49.562, 20.614 49.562)>, 'attractiveness': 57.906000000000006}}
# {0: {'osmid': 229443216, 'oneway': False, 'lanes': '2', 'name': 'Józefa Piłsudskiego', 'highway': 'tertiary', 'reversed': False, 'length': 49.2325, 'attractiveness': 98.465}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 38.695, 'geometry': <LINESTRING (20.613 49.561, 20.612 49.561, 20.612 49.561)>, 'attractiveness': 77.39}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 5.7805, 'attractiveness': 11.561}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 0.4635, 'attractiveness': 0.927}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 277.92150000000004, 'geometry': <LINESTRING (20.611 49.561, 20.611 49.561, 20.611 49.561, 20.611 49.561, 20....>, 'attractiveness': 555.8430000000001}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 170.713, 'geometry': <LINESTRING (20.605 49.558, 20.604 49.558, 20.603 49.557, 20.601 49.556)>, 'attractiveness': 341.426}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 120.05199999999999, 'geometry': <LINESTRING (20.601 49.556, 20.6 49.556, 20.6 49.555, 20.599 49.555, 20.599 ...>, 'attractiveness': 240.10399999999998}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 87.979, 'geometry': <LINESTRING (20.599 49.555, 20.598 49.554, 20.598 49.554, 20.598 49.554)>, 'attractiveness': 175.958}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 12.2175, 'attractiveness': 24.435}}
# {0: {'osmid': 246056264, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 106.20500000000001, 'geometry': <LINESTRING (20.597 49.553, 20.597 49.553, 20.597 49.553, 20.597 49.552, 20....>, 'attractiveness': 212.41000000000003}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 159.926, 'geometry': <LINESTRING (20.596 49.552, 20.594 49.551, 20.592 49.55)>, 'attractiveness': 319.852}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 75.242, 'attractiveness': 150.484}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 32.9225, 'attractiveness': 65.845}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 58.7325, 'geometry': <LINESTRING (20.589 49.549, 20.588 49.549, 20.588 49.549)>, 'attractiveness': 117.465}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 95.64849999999998, 'geometry': <LINESTRING (20.588 49.549, 20.587 49.549, 20.586 49.548, 20.586 49.548)>, 'attractiveness': 191.29699999999997}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 18.4095, 'attractiveness': 36.819}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 9.3445, 'attractiveness': 18.689}}
# {0: {'osmid': 472854899, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 111.1865, 'geometry': <LINESTRING (20.585 49.548, 20.585 49.548, 20.584 49.547, 20.583 49.547, 20....>, 'attractiveness': 222.373}}
# {0: {'osmid': 472854898, 'lanes': '2', 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 119.41250000000001, 'geometry': <LINESTRING (20.582 49.547, 20.582 49.547, 20.581 49.547, 20.581 49.546, 20....>, 'attractiveness': 238.82500000000002}}
# {0: {'osmid': 1288985445, 'oneway': True, 'lanes': '1', 'highway': 'tertiary', 'reversed': False, 'length': 7.64, 'attractiveness': 15.28}}
# {0: {'osmid': 1288985437, 'oneway': True, 'lanes': '1', 'highway': 'tertiary', 'reversed': False, 'length': 10.1375, 'attractiveness': 20.275}}
# {0: {'osmid': 364916627, 'highway': 'tertiary', 'junction': 'roundabout', 'oneway': True, 'reversed': False, 'length': 1.5055, 'attractiveness': 3.011}}
# {0: {'osmid': [364916627, 1173985980], 'highway': 'tertiary', 'junction': 'roundabout', 'oneway': True, 'reversed': False, 'length': 4.516, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546, 20.578 49.546, 20....>, 'attractiveness': 9.032}}
# {0: {'osmid': 1173985980, 'highway': 'tertiary', 'junction': 'roundabout', 'oneway': True, 'reversed': False, 'length': 2.2445, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546)>, 'attractiveness': 4.489}}
# {0: {'osmid': 1173985980, 'highway': 'tertiary', 'junction': 'roundabout', 'oneway': True, 'reversed': False, 'length': 5.895499999999999, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546, 20.578 49.546, 20....>, 'attractiveness': 11.790999999999999}}
# {0: {'osmid': 1173985980, 'highway': 'tertiary', 'junction': 'roundabout', 'oneway': True, 'reversed': False, 'length': 2.267, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546)>, 'attractiveness': 4.534}}
# {0: {'osmid': 1288985442, 'oneway': True, 'highway': 'tertiary', 'reversed': False, 'length': 8.3315, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546)>, 'attractiveness': 16.663}}
# {0: {'osmid': 388057775, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 23.262, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.578 49.546, 20.578 49.546)>, 'attractiveness': 46.524}}
# {0: {'osmid': 388057775, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 45.134, 'geometry': <LINESTRING (20.578 49.546, 20.578 49.546, 20.577 49.545, 20.577 49.545, 20....>, 'attractiveness': 90.268}}
# {0: {'osmid': 388057775, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 65.08, 'geometry': <LINESTRING (20.577 49.545, 20.577 49.545, 20.576 49.544, 20.576 49.544)>, 'attractiveness': 130.16}}
# {0: {'osmid': 388057775, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 40.78, 'geometry': <LINESTRING (20.576 49.544, 20.576 49.544, 20.576 49.544, 20.576 49.543)>, 'attractiveness': 81.56}}
# {0: {'osmid': [388057765, 388057775], 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 4.0275, 'geometry': <LINESTRING (20.576 49.543, 20.576 49.543, 20.576 49.543)>, 'attractiveness': 8.055}}
# {0: {'osmid': [608131022, 1279458383], 'highway': 'tertiary', 'oneway': False, 'reversed': [False, True], 'length': 61.2315, 'maxspeed': '50', 'geometry': <LINESTRING (20.576 49.543, 20.576 49.543, 20.575 49.543, 20.574 49.543)>, 'attractiveness': 122.463}}
# {0: {'osmid': 608131022, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 17.324, 'attractiveness': 34.648}}
# {0: {'osmid': 608131022, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 16.329, 'geometry': <LINESTRING (20.574 49.542, 20.574 49.542, 20.574 49.542)>, 'attractiveness': 32.658}}
# {0: {'osmid': 608131022, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 71.2975, 'geometry': <LINESTRING (20.574 49.542, 20.573 49.542, 20.572 49.541)>, 'attractiveness': 142.595}}
# {0: {'osmid': 608131022, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 1.3525, 'attractiveness': 2.705}}
# {0: {'osmid': 608131022, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 83.181, 'geometry': <LINESTRING (20.572 49.541, 20.572 49.541, 20.572 49.541, 20.571 49.54)>, 'attractiveness': 166.362}}
# {0: {'osmid': [525134553, 726981722, 608131022], 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 82.65700000000001, 'bridge': 'yes', 'geometry': <LINESTRING (20.571 49.54, 20.571 49.54, 20.57 49.539, 20.57 49.539, 20.57 4...>, 'attractiveness': 165.31400000000002}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 22.217, 'geometry': <LINESTRING (20.57 49.539, 20.57 49.539, 20.57 49.538)>, 'attractiveness': 44.434}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 43.2395, 'attractiveness': 86.479}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 24.837, 'geometry': <LINESTRING (20.569 49.538, 20.569 49.538, 20.569 49.537)>, 'attractiveness': 49.674}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 11.387, 'attractiveness': 22.774}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 98.1975, 'geometry': <LINESTRING (20.569 49.537, 20.568 49.537, 20.568 49.536, 20.568 49.536, 20....>, 'attractiveness': 196.395}}
# {0: {'osmid': 525134553, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 8.1815, 'attractiveness': 16.363}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 61.711, 'geometry': <LINESTRING (20.567 49.535, 20.567 49.535, 20.566 49.535)>, 'attractiveness': 123.422}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 109.145, 'geometry': <LINESTRING (20.566 49.535, 20.564 49.534, 20.563 49.534, 20.563 49.534)>, 'attractiveness': 218.29}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 14.214, 'attractiveness': 28.428}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 63.4005, 'geometry': <LINESTRING (20.563 49.534, 20.562 49.534, 20.561 49.534, 20.561 49.534)>, 'attractiveness': 126.801}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 43.4845, 'geometry': <LINESTRING (20.561 49.534, 20.56 49.534, 20.56 49.534, 20.56 49.534)>, 'attractiveness': 86.969}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 91.8005, 'geometry': <LINESTRING (20.56 49.534, 20.56 49.534, 20.559 49.534, 20.559 49.533, 20.55...>, 'attractiveness': 183.601}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 61.39750000000001, 'geometry': <LINESTRING (20.558 49.533, 20.557 49.533, 20.556 49.532)>, 'attractiveness': 122.79500000000002}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 26.4005, 'attractiveness': 52.801}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 59.127500000000005, 'geometry': <LINESTRING (20.556 49.532, 20.555 49.532, 20.555 49.532, 20.554 49.532, 20....>, 'attractiveness': 118.25500000000001}}
# {0: {'osmid': 525134555, 'oneway': False, 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 462.06250000000006, 'geometry': <LINESTRING (20.554 49.532, 20.554 49.532, 20.554 49.532, 20.554 49.532, 20....>, 'attractiveness': 924.1250000000001}}
# {0: {'osmid': [818784536, 818708781, 818784535], 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 96.24, 'bridge': 'yes', 'name': 'Velo Dunajec', 'geometry': <LINESTRING (20.542 49.532, 20.542 49.532, 20.542 49.532, 20.542 49.533, 20....>, 'attractiveness': 192.48}}
# {0: {'osmid': 818708781, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 2.8655, 'attractiveness': 5.731}}
# {0: {'osmid': 818708781, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 393.0335, 'geometry': <LINESTRING (20.542 49.534, 20.54 49.533, 20.54 49.533, 20.54 49.533, 20.538...>, 'attractiveness': 786.067}}
# {0: {'osmid': 818708781, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 158.8755, 'geometry': <LINESTRING (20.531 49.533, 20.53 49.533, 20.53 49.533, 20.529 49.533, 20.52...>, 'attractiveness': 317.751}}
# {0: {'osmid': 818708780, 'name': 'Velo Dunajec', 'highway': 'service', 'oneway': False, 'reversed': False, 'length': 75.27199999999999, 'geometry': <LINESTRING (20.527 49.533, 20.527 49.532, 20.527 49.532, 20.527 49.532)>, 'attractiveness': 75.27199999999999}}
# {0: {'osmid': 623825756, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 135.3185, 'geometry': <LINESTRING (20.527 49.532, 20.527 49.532, 20.526 49.532, 20.525 49.531, 20....>, 'attractiveness': 270.637}}
# {0: {'osmid': 623825756, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 346.38899999999995, 'geometry': <LINESTRING (20.523 49.531, 20.523 49.531, 20.523 49.531, 20.523 49.531, 20....>, 'attractiveness': 692.7779999999999}}
# {0: {'osmid': 623825756, 'name': 'Velo Dunajec', 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 143.66450000000003, 'geometry': <LINESTRING (20.516 49.527, 20.516 49.527, 20.515 49.527, 20.514 49.526, 20....>, 'attractiveness': 287.32900000000006}}
# {0: {'osmid': 623825757, 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 16.2645, 'geometry': <LINESTRING (20.513 49.526, 20.512 49.526, 20.512 49.526)>, 'attractiveness': 32.529}}
# {0: {'osmid': [388052009, 623825757, 295561174], 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 89.687, 'bridge': 'yes', 'geometry': <LINESTRING (20.512 49.526, 20.512 49.526, 20.513 49.525, 20.513 49.525, 20....>, 'attractiveness': 179.374}}
# {0: {'osmid': 389254092, 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 25.846000000000004, 'geometry': <LINESTRING (20.513 49.525, 20.512 49.524, 20.512 49.524)>, 'attractiveness': 51.69200000000001}}
# {0: {'osmid': 389254092, 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 10.098, 'geometry': <LINESTRING (20.512 49.524, 20.512 49.524, 20.512 49.524)>, 'attractiveness': 20.196}}
# {0: {'osmid': [218067992, 218067996], 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 27.271, 'bridge': 'yes', 'geometry': <LINESTRING (20.512 49.524, 20.512 49.524, 20.512 49.524, 20.512 49.524)>, 'attractiveness': 54.542}}
# {0: {'osmid': 389202543, 'oneway': False, 'highway': 'tertiary', 'reversed': False, 'length': 215.85100000000003, 'geometry': <LINESTRING (20.512 49.524, 20.511 49.524, 20.511 49.524, 20.51 49.524, 20.5...>, 'attractiveness': 431.70200000000006}}
# {0: {'osmid': 389254093, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 153.3895, 'geometry': <LINESTRING (20.506 49.524, 20.506 49.524, 20.505 49.523, 20.505 49.523, 20....>, 'attractiveness': 306.779}}
# {0: {'osmid': [1154064050, 389202538, 389254093], 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 229.7425, 'bridge': 'yes', 'geometry': <LINESTRING (20.503 49.522, 20.503 49.522, 20.502 49.522, 20.502 49.522, 20....>, 'attractiveness': 459.485}}
# {0: {'osmid': 1154064050, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 76.4665, 'geometry': <LINESTRING (20.496 49.522, 20.496 49.522, 20.495 49.522, 20.494 49.522)>, 'attractiveness': 152.933}}
# {0: {'osmid': [1154064056, 1154064049, 1154064050], 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 274.69800000000004, 'bridge': 'yes', 'geometry': <LINESTRING (20.494 49.522, 20.492 49.522, 20.491 49.522, 20.491 49.522, 20....>, 'attractiveness': 549.3960000000001}}
# {0: {'osmid': [1154064056, 275958804, 1154064055], 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 279.5885, 'bridge': 'yes', 'geometry': <LINESTRING (20.487 49.523, 20.487 49.523, 20.487 49.523, 20.486 49.523, 20....>, 'attractiveness': 559.177}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 78.696, 'geometry': <LINESTRING (20.482 49.526, 20.482 49.526, 20.482 49.526, 20.482 49.526, 20....>, 'attractiveness': 157.392}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 144.8895, 'geometry': <LINESTRING (20.48 49.526, 20.48 49.526, 20.48 49.526, 20.479 49.525, 20.479...>, 'attractiveness': 289.779}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 52.123999999999995, 'geometry': <LINESTRING (20.477 49.525, 20.476 49.525, 20.476 49.525, 20.475 49.525)>, 'attractiveness': 104.24799999999999}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 151.4085, 'geometry': <LINESTRING (20.475 49.525, 20.475 49.525, 20.474 49.525, 20.473 49.525, 20....>, 'attractiveness': 302.817}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 49.11450000000001, 'geometry': <LINESTRING (20.471 49.525, 20.471 49.525, 20.471 49.526, 20.47 49.526, 20.4...>, 'attractiveness': 98.22900000000001}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 112.86800000000001, 'geometry': <LINESTRING (20.47 49.526, 20.47 49.526, 20.469 49.526, 20.469 49.526, 20.46...>, 'attractiveness': 225.73600000000002}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 343.602, 'geometry': <LINESTRING (20.467 49.526, 20.467 49.526, 20.466 49.525, 20.466 49.525, 20....>, 'attractiveness': 687.204}}
# {0: {'osmid': 275958804, 'highway': 'tertiary', 'oneway': False, 'reversed': False, 'length': 23.326500000000003, 'geometry': <LINESTRING (20.458 49.524, 20.458 49.524, 20.458 49.523, 20.458 49.523, 20....>, 'attractiveness': 46.653000000000006}}
# {0: {'osmid': [807365993, 807365994, 807365995, 807365996, 302520019], 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 1073.25, 'bridge': 'yes', 'width': '3', 'geometry': <LINESTRING (20.458 49.523, 20.457 49.523, 20.457 49.523, 20.457 49.523, 20....>, 'attractiveness': 1073.25}}
# {0: {'osmid': 807365993, 'highway': 'residential', 'width': '3', 'oneway': False, 'reversed': False, 'length': 346.865, 'geometry': <LINESTRING (20.453 49.515, 20.453 49.514, 20.452 49.514, 20.452 49.514, 20....>, 'attractiveness': 346.865}}
# {0: {'osmid': 807365993, 'highway': 'residential', 'width': '3', 'oneway': False, 'reversed': False, 'length': 401.686, 'geometry': <LINESTRING (20.452 49.512, 20.452 49.511, 20.452 49.511, 20.451 49.511, 20....>, 'attractiveness': 401.686}}
# {0: {'osmid': 388522790, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 484.6580000000001, 'geometry': <LINESTRING (20.451 49.508, 20.451 49.508, 20.451 49.508, 20.451 49.508, 20....>, 'attractiveness': 484.6580000000001}}
# {0: {'osmid': 388522790, 'highway': 'track', 'oneway': False, 'reversed': False, 'length': 181.373, 'geometry': <LINESTRING (20.447 49.508, 20.447 49.508, 20.447 49.508, 20.447 49.508, 20....>, 'attractiveness': 181.373}}
# {0: {'osmid': 161696403, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 10.871, 'attractiveness': 10.871}}
# {0: {'osmid': 931978331, 'highway': 'footway', 'oneway': False, 'reversed': False, 'length': 102.50299999999999, 'geometry': <LINESTRING (20.445 49.508, 20.444 49.508, 20.444 49.507, 20.444 49.507, 20....>, 'attractiveness': 102.50299999999999}}
# {0: {'osmid': [931978330, 931978331], 'highway': 'footway', 'oneway': False, 'reversed': False, 'length': 264.721, 'geometry': <LINESTRING (20.444 49.507, 20.444 49.507, 20.444 49.507, 20.443 49.507, 20....>, 'attractiveness': 264.721}}
# {0: {'osmid': 931978335, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 140.755, 'geometry': <LINESTRING (20.441 49.507, 20.441 49.507, 20.44 49.507, 20.44 49.507, 20.43...>, 'attractiveness': 140.755}}
# {0: {'osmid': 931978335, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 44.647, 'attractiveness': 44.647}}
# {0: {'osmid': 931978335, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 99.937, 'geometry': <LINESTRING (20.438 49.507, 20.438 49.507, 20.437 49.507, 20.437 49.507)>, 'attractiveness': 99.937}}
# {0: {'osmid': [931978328, 932035148], 'highway': 'footway', 'oneway': False, 'reversed': True, 'length': 382.98699999999997, 'geometry': <LINESTRING (20.437 49.507, 20.436 49.507, 20.436 49.507, 20.435 49.507, 20....>, 'attractiveness': 382.98699999999997}}
# {0: {'osmid': [931978328, 932035147], 'highway': 'footway', 'oneway': False, 'reversed': True, 'length': 520.7580000000002, 'geometry': <LINESTRING (20.432 49.508, 20.432 49.508, 20.431 49.508, 20.431 49.508, 20....>, 'attractiveness': 520.7580000000002}}
# {0: {'osmid': 931978336, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 681.6470000000002, 'geometry': <LINESTRING (20.426 49.509, 20.426 49.509, 20.426 49.509, 20.426 49.509, 20....>, 'attractiveness': 681.6470000000002}}
# {0: {'osmid': 1055182910, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 129.47899999999998, 'geometry': <LINESTRING (20.417 49.509, 20.417 49.509, 20.417 49.509, 20.417 49.509, 20....>, 'attractiveness': 129.47899999999998}}
# {0: {'osmid': 1055182910, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 4.035, 'attractiveness': 4.035}}
# {0: {'osmid': 931978336, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 93.616, 'geometry': <LINESTRING (20.415 49.51, 20.415 49.51, 20.415 49.509, 20.414 49.509, 20.41...>, 'attractiveness': 93.616}}
# {0: {'osmid': 931978336, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 286.69899999999996, 'geometry': <LINESTRING (20.414 49.509, 20.414 49.509, 20.413 49.509, 20.413 49.509, 20....>, 'attractiveness': 286.69899999999996}}
# {0: {'osmid': 948201306, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 26.57, 'geometry': <LINESTRING (20.41 49.509, 20.41 49.509, 20.41 49.509)>, 'attractiveness': 26.57}}
# {0: {'osmid': 280961218, 'highway': 'path', 'oneway': False, 'reversed': True, 'length': 335.39099999999996, 'geometry': <LINESTRING (20.41 49.509, 20.41 49.509, 20.41 49.509, 20.409 49.509, 20.409...>, 'attractiveness': 335.39099999999996}, 1: {'osmid': 763932032, 'highway': 'track', 'oneway': False, 'reversed': True, 'length': 337.553, 'geometry': <LINESTRING (20.41 49.509, 20.41 49.509, 20.41 49.509, 20.41 49.509, 20.409 ...>, 'attractiveness': 337.553}}
# {0: {'osmid': [1000020816, 763932033, 763932034], 'highway': ['service', 'track'], 'oneway': False, 'reversed': True, 'length': 310.395, 'geometry': <LINESTRING (20.406 49.51, 20.406 49.511, 20.406 49.511, 20.406 49.511, 20.4...>, 'attractiveness': 310.395}}
# {0: {'osmid': 763932034, 'highway': 'service', 'oneway': False, 'reversed': True, 'length': 202.058, 'geometry': <LINESTRING (20.404 49.513, 20.403 49.513, 20.402 49.513, 20.402 49.514, 20....>, 'attractiveness': 202.058}}
# {0: {'osmid': 280961219, 'name': 'Osiedle Czeczugi', 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 34.514, 'geometry': <LINESTRING (20.401 49.514, 20.401 49.514, 20.402 49.514, 20.402 49.514, 20....>, 'attractiveness': 34.514}}
# {0: {'osmid': 330031774, 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 62.357, 'geometry': <LINESTRING (20.402 49.514, 20.402 49.514, 20.402 49.514, 20.402 49.514, 20....>, 'attractiveness': 62.357}}
# {0: {'osmid': 115628349, 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 111.455, 'geometry': <LINESTRING (20.402 49.515, 20.402 49.515, 20.402 49.515, 20.401 49.515, 20....>, 'attractiveness': 111.455}}
# {0: {'osmid': 115628349, 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 95.86800000000001, 'geometry': <LINESTRING (20.401 49.515, 20.401 49.515, 20.4 49.515, 20.4 49.515, 20.4 49...>, 'attractiveness': 95.86800000000001}}
# {0: {'osmid': [340488792, 340488793, 112366858], 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 93.625, 'bridge': 'yes', 'geometry': <LINESTRING (20.4 49.515, 20.4 49.515, 20.399 49.515, 20.399 49.516, 20.399 ...>, 'attractiveness': 93.625}}
# {0: {'osmid': 1040770469, 'oneway': False, 'lanes': '2', 'ref': '969', 'highway': 'secondary', 'maxspeed': '50', 'reversed': True, 'length': 13.237, 'attractiveness': 13.237}}
# {0: {'osmid': [179894330, 330028826, 179894340], 'oneway': False, 'lanes': '2', 'ref': '969', 'highway': 'secondary', 'maxspeed': '50', 'reversed': True, 'length': 105.54899999999999, 'bridge': 'yes', 'geometry': <LINESTRING (20.399 49.516, 20.399 49.516, 20.4 49.517, 20.4 49.517)>, 'attractiveness': 105.54899999999999}}
# {0: {'osmid': 401559093, 'name': 'Osiedle Rzeka', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 27.357499999999998, 'geometry': <LINESTRING (20.4 49.517, 20.4 49.517, 20.4 49.517)>, 'attractiveness': 54.714999999999996}}
# {0: {'osmid': 401559093, 'name': 'Osiedle Rzeka', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 53.796, 'geometry': <LINESTRING (20.4 49.517, 20.399 49.517, 20.399 49.517, 20.399 49.518, 20.39...>, 'attractiveness': 107.592}}
# {0: {'osmid': [330028853, 401559091, 401559093], 'name': 'Osiedle Rzeka', 'highway': 'tertiary', 'oneway': False, 'reversed': True, 'length': 226.10000000000002, 'bridge': 'yes', 'geometry': <LINESTRING (20.398 49.518, 20.398 49.518, 20.397 49.518, 20.397 49.518, 20....>, 'attractiveness': 452.20000000000005}}
# ...
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 13.5995, 'attractiveness': 27.199}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 8.7695, 'attractiveness': 17.539}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 27.3925, 'attractiveness': 54.785}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 7.7625, 'attractiveness': 15.525}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 1.6745, 'attractiveness': 3.349}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 8.3745, 'attractiveness': 16.749}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 1.661, 'attractiveness': 3.322}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 26.5635, 'geometry': <LINESTRING (20.089 49.478, 20.088 49.478, 20.088 49.479)>, 'attractiveness': 53.127}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 36.0555, 'attractiveness': 72.111}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 18.901, 'attractiveness': 37.802}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 17.034, 'attractiveness': 34.068}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 16.4995, 'attractiveness': 32.999}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 151.351, 'geometry': <LINESTRING (20.086 49.479, 20.082 49.48, 20.082 49.48)>, 'attractiveness': 302.702}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 1.3255, 'attractiveness': 2.651}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 58.1895, 'attractiveness': 116.379}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 81.2175, 'geometry': <LINESTRING (20.08 49.48, 20.08 49.48, 20.078 49.481)>, 'attractiveness': 162.435}}
# {0: {'osmid': 101094311, 'oneway': False, 'lanes': '2', 'name': 'Nowotarska', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 5.3205, 'attractiveness': 10.641}}
# {0: {'osmid': 205185452, 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 105.701, 'attractiveness': 105.701}}
# {0: {'osmid': 205185452, 'highway': 'residential', 'oneway': False, 'reversed': False, 'length': 152.224, 'geometry': <LINESTRING (20.078 49.482, 20.079 49.482, 20.079 49.482, 20.079 49.483, 20....>, 'attractiveness': 152.224}}
# {0: {'osmid': 205185451, 'name': 'Stanisławy i Józefa Papieżów', 'highway': 'cycleway', 'oneway': False, 'reversed': True, 'length': 16.3155, 'geometry': <LINESTRING (20.08 49.483, 20.079 49.483, 20.079 49.483)>, 'attractiveness': 32.631}}
# {0: {'osmid': 205185451, 'name': 'Stanisławy i Józefa Papieżów', 'highway': 'cycleway', 'oneway': False, 'reversed': True, 'length': 62.5985, 'geometry': <LINESTRING (20.079 49.483, 20.079 49.483, 20.078 49.484, 20.078 49.484)>, 'attractiveness': 125.197}}
# {0: {'osmid': [205185451, 291901365], 'name': 'Stanisławy i Józefa Papieżów', 'highway': 'cycleway', 'oneway': False, 'reversed': [False, True], 'length': 68.51199999999999, 'geometry': <LINESTRING (20.078 49.484, 20.078 49.484, 20.078 49.484, 20.077 49.484, 20....>, 'attractiveness': 137.02399999999997}}
# {0: {'osmid': [291901365, 696637814, 696637815], 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 462.20500000000004, 'bridge': 'yes', 'geometry': <LINESTRING (20.076 49.485, 20.076 49.485, 20.076 49.485, 20.075 49.485, 20....>, 'attractiveness': 924.4100000000001}}
# {0: {'osmid': 657654480, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 81.13150000000002, 'geometry': <LINESTRING (20.065 49.488, 20.064 49.488, 20.064 49.487, 20.063 49.487, 20....>, 'attractiveness': 162.26300000000003}}
# {0: {'osmid': 657654480, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 62.781, 'geometry': <LINESTRING (20.063 49.487, 20.063 49.487, 20.062 49.487, 20.062 49.487, 20....>, 'attractiveness': 125.562}}
# {0: {'osmid': 696639132, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 75.47, 'geometry': <LINESTRING (20.061 49.488, 20.061 49.488, 20.06 49.487, 20.059 49.487)>, 'attractiveness': 150.94}}
# {0: {'osmid': 696639132, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 644.5305000000001, 'geometry': <LINESTRING (20.059 49.487, 20.059 49.487, 20.058 49.487, 20.058 49.487, 20....>, 'attractiveness': 1289.0610000000001}}
# {0: {'osmid': 696639132, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 156.59449999999998, 'geometry': <LINESTRING (20.044 49.484, 20.044 49.484, 20.044 49.483, 20.043 49.483, 20....>, 'attractiveness': 313.18899999999996}}
# {0: {'osmid': 627427946, 'highway': 'cycleway', 'oneway': False, 'reversed': False, 'length': 11.216, 'attractiveness': 22.432}}
# {0: {'osmid': 916317828, 'highway': 'service', 'oneway': False, 'reversed': True, 'length': 4.943, 'attractiveness': 4.943}}
# {0: {'osmid': [330071865, 306164865, 26552169], 'lanes': '2', 'name': 'Waksmundzka', 'highway': 'tertiary', 'maxspeed': '50', 'oneway': False, 'reversed': [False, True], 'length': 75.02099999999999, 'bridge': 'yes', 'geometry': <LINESTRING (20.042 49.481, 20.041 49.481, 20.04 49.481, 20.04 49.482)>, 'attractiveness': 150.04199999999997}}
# {0: {'osmid': 306164869, 'oneway': True, 'lanes': '1', 'name': 'Waksmundzka', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 9.6685, 'geometry': <LINESTRING (20.04 49.482, 20.039 49.482, 20.039 49.482)>, 'attractiveness': 19.337}}
# {0: {'osmid': 306164869, 'oneway': True, 'lanes': '1', 'name': 'Waksmundzka', 'highway': 'tertiary', 'maxspeed': '50', 'reversed': False, 'length': 10.8795, 'geometry': <LINESTRING (20.039 49.482, 20.039 49.482, 20.039 49.482)>, 'attractiveness': 21.759}}
# {0: {'osmid': 306164867, 'oneway': True, 'name': 'Waksmundzka', 'highway': 'residential', 'reversed': False, 'length': 22.272, 'attractiveness': 22.272}}
# {0: {'osmid': 306164867, 'oneway': True, 'name': 'Waksmundzka', 'highway': 'residential', 'reversed': False, 'length': 16.282, 'attractiveness': 16.282}}
# {0: {'osmid': 101118306, 'name': 'Waksmundzka', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 139.797, 'geometry': <LINESTRING (20.039 49.482, 20.038 49.482, 20.037 49.482, 20.037 49.482, 20....>, 'attractiveness': 139.797}}
# {0: {'osmid': 101118232, 'name': 'Świętej Doroty', 'highway': 'residential', 'oneway': False, 'reversed': True, 'length': 91.415, 'geometry': <LINESTRING (20.037 49.482, 20.037 49.482, 20.037 49.482, 20.037 49.482, 20....>, 'attractiveness': 91.415}}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79b154ddf3b03022bf24e97479b8bb50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79b154ddf3b03022bf24e97479b8bb50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79b154ddf3b03022bf24e97479b8bb50 = L.map(
#                 &quot;map_79b154ddf3b03022bf24e97479b8bb50&quot;,
#                 {
#                     center: [49.639989612887234, 20.69236640147815],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df99615f20f43060417ddf59b26e659 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9df99615f20f43060417ddf59b26e659.addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_8401fa4b8aa8983bf37c0abc557dc3b3 = L.polyline(
#                 [[49.6400846, 20.6923858], [49.6389847, 20.6921982]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_a4862aacf58304c7b615b876d56ccede = L.polyline(
#                 [[49.6389847, 20.6921982], [49.6389673, 20.6915437]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_82f8d78a18fe08ab3f7661c98763c21a = L.polyline(
#                 [[49.6389673, 20.6915437], [49.6388596, 20.6904843]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_d0ae2ebd230bd8b79d6796799a0a01a1 = L.polyline(
#                 [[49.6388596, 20.6904843], [49.6388492, 20.6903287]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_8394f76d6ced34cb4f6a3bbb6262cf20 = L.polyline(
#                 [[49.6388492, 20.6903287], [49.6387886, 20.6898314]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_79b154ddf3b03022bf24e97479b8bb50);
#
#
#             var poly_line_1d9b62dd600bd50237cb256fe9327081 = L.polyline(
#                 [[49.6387886, 20.6898314], [49.6387428, 20.6885126]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;no
